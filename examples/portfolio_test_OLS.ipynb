# %%
import sys
sys.path.append('../src')
from vector_backtest_OLS import *
from datetime import *
import matplotlib.pyplot as plt

# %%
# here we perform a vectorised backtest of several pairs of stocks using OLS to calculate the hedge ratio

t = datetime.now()

p = Portfolio([["JPM", "WFC"],
               ["AMD", "NVDA"], 
               ["MSFT", "AAPL"], 
               ["NEE", "DUK"],  
               ["GOOG", "META"]], date(2021, 1, 1), date(2022, 3, 1), 30, 1000)
p.makePortfolio()

print(datetime.now()-t)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# 0:00:09.114322

# %%
plt.plot(p.portfolio, alpha = 0.35)
plt.plot(p.dot_ret[:-1], color='black', label="Total Return")
plt.xticks(rotation='45')
plt.legend(p.portfolio.columns)
plt.figure(figsize=(15,10))
plt.show()
